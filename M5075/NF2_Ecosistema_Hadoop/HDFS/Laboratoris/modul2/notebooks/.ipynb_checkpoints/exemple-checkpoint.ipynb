# %%
import findspark
findspark.init()

from pyspark.sql import SparkSession
import pandas as pd
import numpy as np

# %%
# Crear SparkSession
spark = SparkSession.builder \
    .appName("Ejemplo PySpark") \
    .master("spark://master:7077") \
    .config("spark.hadoop.fs.defaultFS", "hdfs://master:9000") \
    .getOrCreate()

print(f"✅ Spark {spark.version} iniciado")
print(f"✅ Master: {spark.sparkContext.master}")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/17 09:54:05 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# ✅ Spark 3.5.0 iniciado
# ✅ Master: spark://master:7077

# %%
# Crear DataFrame de ejemplo
data = [("Alice", 25), ("Bob", 30), ("Charlie", 35)]
df = spark.createDataFrame(data, ["nombre", "edad"])

df.show()
# Out:
# +-------+----+
# | nombre|edad|
# +-------+----+
# |  Alice|  25|
# |    Bob|  30|
# |Charlie|  35|
# +-------+----+

# %%
# Guardar en HDFS (módulo1)
df.write.mode("overwrite").parquet("hdfs://master:9000/user/hadoop/ejemplo_spark.parquet")
print("✅ Datos guardados en HDFS")
# Out:
# [Stage 2:=============================>                             (1 + 1) / 2]
# ✅ Datos guardados en HDFS

# %%
# Leer desde HDFS
df_hdfs = spark.read.parquet("hdfs://master:9000/user/hadoop/ejemplo_spark.parquet")
df_hdfs.show()
print("✅ Datos leídos desde HDFS")
# Out:
# +-------+----+
# | nombre|edad|
# +-------+----+
# |    Bob|  30|
# |Charlie|  35|
# |  Alice|  25|
# +-------+----+
#
# ✅ Datos leídos desde HDFS

# %%
# Operaciones con DataFrame
df_hdfs.filter(df_hdfs.edad > 28).show()
# Out:
# +-------+----+
# | nombre|edad|
# +-------+----+
# |    Bob|  30|
# |Charlie|  35|
# +-------+----+

# %%
spark.stop()
